# %% [markdown]
# This notebook demonstrates how simple formation energy models can be trained on OQMD data using magpie descriptors (based on https://journals.aps.org/prb/abstract/10.1103/PhysRevB.96.024104) The 271 descriptors for each entry in OQMD  were precomputed using MatMiner, and provided as a pickle file.

# %%
import pandas as pd
import numpy as np
import time
import boto3
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import KFold
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error
from tqdm import tqdm

# %% [markdown]
# Download dataframe containing precomputed magpie descriptors, and formation energies: `s3://hackathon2020-prod/data/oqmd_1.2_voronoi_magpie_fingerprints.pickle`.

# %%
oqmd_pickle = 'oqmd_1.2_voronoi_magpie_fingerprints.pickle'

# %%
def hook(t):
  def inner(bytes_amount):
    t.update(bytes_amount)
  return inner
#session = boto3.session.Session(profile_name='hack2020')
#s3 = session.client('s3')
s3 = boto3.client('s3')
filesize = boto3.resource('s3').Object('hackathon2020-prod', 'data/' + oqmd_pickle).content_length
with tqdm(total=filesize, unit='B', unit_scale=True, desc=oqmd_pickle) as t:
    s3.download_file('hackathon2020-prod', 'data/' + oqmd_pickle, oqmd_pickle, Callback=hook(t))
# Out:
# oqmd_1.2_voronoi_magpie_fingerprints.pickle: 100%|██████████| 1.34G/1.34G [00:10<00:00, 130MB/s]

# %% [markdown]
# Load into dataframe.

# %%
df = pd.read_pickle(oqmd_pickle)

# %% [markdown]
# Since the data is in a pandas dataframe, we can conveniently inspect it. `delta_e` is the target column we would like to predict. We also will not need `oqmd_id` and `Composition` columns in training the model. The rest of the columns pertain to magpie descriptors computed for each OQMD entry.

# %%
df.head()
# Out:
#         0-norm   10-norm  2-norm   3-norm    5-norm    7-norm Composition  \
# 792841       4  0.287175     0.5  0.39685  0.329877  0.304753     MnInCuW
# 792842       4  0.287175     0.5  0.39685  0.329877  0.304753     MnCuSnW
# 792843       4  0.287175     0.5  0.39685  0.329877  0.304753     MnCuSbW
# 792844       4  0.287175     0.5  0.39685  0.329877  0.304753     MnTlCuW
# 792845       4  0.287175     0.5  0.39685  0.329877  0.304753     MnCuPbW
#
#         MagpieData avg_dev AtomicWeight  MagpieData avg_dev Column  \
# 792841                        45.043489                       2.75
# 792842                        46.016489                       3.00
# 792843                        46.778989                       3.25
# 792844                        67.434814                       2.75
# 792845                        68.138989                       3.00
#
#         MagpieData avg_dev CovalentRadius  ...  \
# 792841                              9.125  ...
# 792842                              9.500  ...
# 792843                              9.500  ...
# 792844                              9.000  ...
# 792845                              9.250  ...
#
#         range local difference in NfUnfilled  \
# 792841                                   0.0
# 792842                                   0.0
# 792843                                   0.0
# 792844                                   0.0
# 792845                                   0.0
#
#         range local difference in NfValence  \
# 792841                         1.086387e+01
# 792842                         1.086387e+01
# 792843                         1.086387e+01
# 792844                         4.956036e-13
# 792845                         7.826628e-12
#
#         range local difference in NpUnfilled  \
# 792841                              3.879954
# 792842                              3.103963
# 792843                              2.327972
# 792844                              3.879954
# 792845                              3.103963
#
#         range local difference in NpValence  \
# 792841                             0.775991
# 792842                             1.551982
# 792843                             2.327972
# 792844                             0.775991
# 792845                             1.551982
#
#         range local difference in NsUnfilled  \
# 792841                              0.775991
# 792842                              0.775991
# 792843                              0.775991
# 792844                              0.775991
# 792845                              0.775991
#
#         range local difference in NsValence  range local difference in Number  \
# 792841                             0.775991                         19.399769
# 792842                             0.775991                         18.623778
# 792843                             0.775991                         17.847788
# 792844                             0.775991                          5.431935
# 792845                             0.775991                          6.207926
#
#         range local difference in Row  \
# 792841                   7.759908e-01
# 792842                   7.759908e-01
# 792843                   7.759908e-01
# 792844                   7.105427e-14
# 792845                   1.118661e-12
#
#         range local difference in SpaceGroupNumber  \
# 792841                                   57.423316
# 792842                                   55.871335
# 792843                                   36.471566
# 792844                                   14.743824
# 792845                                    6.207926
#
#         range neighbor distance variation
# 792841                       1.373040e-11
# 792842                       7.733952e-13
# 792843                       6.699641e-13
# 792844                       3.103073e-14
# 792845                       4.900247e-13
#
# [5 rows x 276 columns]

# %% [markdown]
# Let's now drop the rows that have missing data, and identify any columns that are not np.float64. Straightforward with pandas:

# %%
df = df.dropna(axis=0, how='any')

# %%
not_float_cols = []
for col in df.columns:
    if df[col].dtype != np.float64:
        print(col, df[col].dtype)
        not_float_cols.append(col)
# Out:
# 0-norm int64
# Composition object
# N_species int64
# compound possible bool

# %% [markdown]
# Let's subsample the OQMD entries to be able to train models in a reasonable time frame (only for the purposes of this example, you can switch to the full dataset later)

# %%
df = df.sample(n=50000)

# %% [markdown]
# Prepare our target (y) and feature vectors (X) for training. We'll get rid of some columns without float values:

# %%
y = df['delta_e']
X = df.drop(not_float_cols+['delta_e'], axis=1)

# %%
X
# Out:
#           10-norm    2-norm    3-norm    5-norm    7-norm  \
# 1224542  0.535887  0.707107  0.629961  0.574349  0.552045
# 447589   0.500098  0.612372  0.538609  0.506099  0.501109
# 13173    0.750000  0.770552  0.752308  0.750039  0.750001
# 865100   0.372041  0.577350  0.480750  0.415244  0.389977
# 352112   0.600002  0.663325  0.614463  0.600984  0.600078
# ...           ...       ...       ...       ...       ...
# 756204   0.535887  0.707107  0.629961  0.574349  0.552045
# 444094   0.500098  0.612372  0.538609  0.506099  0.501109
# 529414   0.500098  0.612372  0.538609  0.506099  0.501109
# 842145   0.372041  0.577350  0.480750  0.415244  0.389977
# 298340   0.750001  0.790569  0.759147  0.750616  0.750049
#
#          MagpieData avg_dev AtomicWeight  MagpieData avg_dev Column  \
# 1224542                         0.551981                   0.500000
# 447589                         74.012080                   1.000000
# 13173                          19.531630                   4.687500
# 865100                         35.725591                   4.666667
# 352112                         83.818368                   6.240000
# ...                                  ...                        ...
# 756204                         32.121231                   4.500000
# 444094                         76.293795                   3.750000
# 529414                         62.060527                   3.375000
# 842145                         66.102578                   3.111111
# 298340                         32.263447                   0.000000
#
#          MagpieData avg_dev CovalentRadius  \
# 1224542                           5.000000
# 447589                           33.750000
# 13173                            40.125000
# 865100                           27.777778
# 352112                           62.160000
# ...                                    ...
# 756204                           27.000000
# 444094                           10.875000
# 529414                           25.250000
# 842145                            8.222222
# 298340                            0.375000
#
#          MagpieData avg_dev Electronegativity  MagpieData avg_dev GSbandgap  \
# 1224542                              0.145000                       0.38650
# 447589                               0.106250                       0.00000
# 13173                                0.937500                       0.73875
# 865100                               0.297778                       0.00000
# 352112                               1.051200                       0.00000
# ...                                       ...                           ...
# 756204                               0.140000                       0.00000
# 444094                               0.280000                       0.00000
# 529414                               0.222500                       0.17400
# 842145                               0.331111                       0.00000
# 298340                               0.129375                       0.00000
#
#          ...  range local difference in NfUnfilled  \
# 1224542  ...                              0.000000
# 447589   ...                              4.655945
# 13173    ...                              0.000000
# 865100   ...                              5.999999
# 352112   ...                              3.693981
# ...      ...                                   ...
# 756204   ...                              0.000000
# 444094   ...                              0.000000
# 529414   ...                              8.535898
# 842145   ...                              0.000000
# 298340   ...                              2.021076
#
#          range local difference in NfValence  \
# 1224542                         0.000000e+00
# 447589                          4.655945e+00
# 13173                           0.000000e+00
# 865100                          5.112582e+00
# 352112                          1.477592e+00
# ...                                      ...
# 756204                          0.000000e+00
# 444094                          8.478551e-12
# 529414                          2.327972e+00
# 842145                          6.999997e+00
# 298340                          2.021076e+00
#
#          range local difference in NpUnfilled  \
# 1224542                              0.000002
# 447589                               0.000000
# 13173                                0.809244
# 865100                               2.500000
# 352112                               0.738796
# ...                                       ...
# 756204                               1.519959
# 444094                               3.879954
# 529414                               1.551982
# 842145                               0.000000
# 298340                               0.000000
#
#          range local difference in NpValence  \
# 1224542                             0.000002
# 447589                              0.000000
# 13173                               4.046218
# 865100                              0.500000
# 352112                              1.477592
# ...                                      ...
# 756204                              0.303992
# 444094                              0.775991
# 529414                              3.103963
# 842145                              0.000000
# 298340                              0.000000
#
#          range local difference in NsUnfilled  \
# 1224542                          0.000000e+00
# 447589                           2.301492e-13
# 13173                            0.000000e+00
# 865100                           0.000000e+00
# 352112                           0.000000e+00
# ...                                       ...
# 756204                           0.000000e+00
# 444094                           0.000000e+00
# 529414                           0.000000e+00
# 842145                           0.000000e+00
# 298340                           0.000000e+00
#
#          range local difference in NsValence  \
# 1224542                         0.000000e+00
# 447589                          2.301492e-13
# 13173                           0.000000e+00
# 865100                          0.000000e+00
# 352112                          0.000000e+00
# ...                                      ...
# 756204                          0.000000e+00
# 444094                          0.000000e+00
# 529414                          0.000000e+00
# 842145                          0.000000e+00
# 298340                          0.000000e+00
#
#          range local difference in Number  range local difference in Row  \
# 1224542                          0.000002                   0.000000e+00
# 447589                           4.655945                   9.205969e-13
# 13173                           26.681973                   2.521579e+00
# 865100                          13.609273                   4.999999e-01
# 352112                          43.588971                   2.216388e+00
# ...                                   ...                            ...
# 756204                           8.207781                   6.079838e-01
# 444094                           6.207926                   1.211031e-12
# 529414                          31.039630                   1.551982e+00
# 842145                          20.450330                   8.520971e-01
# 298340                          20.210761                   6.736920e-01
#
#          range local difference in SpaceGroupNumber  \
# 1224542                                4.276338e-06
# 447589                                 8.054002e-12
# 13173                                  1.765699e+02
# 865100                                 2.343267e+01
# 352112                                 1.320000e+02
# ...                                             ...
# 756204                                 9.423749e+00
# 444094                                 2.095175e+01
# 529414                                 6.906318e+01
# 842145                                 1.549999e+01
# 298340                                 3.705306e+01
#
#          range neighbor distance variation
# 1224542                       7.800635e-07
# 447589                        2.017830e-13
# 13173                         9.573547e-02
# 865100                        6.948807e-02
# 352112                        1.224067e-01
# ...                                    ...
# 756204                        1.291819e-02
# 444094                        5.312348e-13
# 529414                        4.571031e-12
# 842145                        6.948735e-02
# 298340                        1.504982e-11
#
# [50000 rows x 271 columns]

# %% [markdown]
# We want to do k-fold cross-validation (CV) to test the performance of our models. Let's do a 3-fold split in this example.

# %%
kf = KFold(n_splits=3, shuffle=True, random_state=42)

# %% [markdown]
# We will collect the predicted and actual formation energies in each fold, to later use in model evaluation. Let's start the CV loop for a linear regression, which will serve as our baseline:

# %%
predictions_LR, truth_LR = [], []

for train_index, test_index in kf.split(X, y):
    
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]
    print(X_train)
    break
    
    # Note we are reinitializing the scaler in each fold.
    scaler = StandardScaler()
    X_train = scaler.fit_transform(X_train)
    
    # This is where we train set of the current fold.
    regressor = LinearRegression()
    regressor.fit(X_train, y_train)
    
    # We should properly standardize our test X with the scaler fitted in this fold.
    X_test = scaler.transform(X_test)
    
    # This is where we make prediction on test set of the current fold.
    predictions_LR += regressor.predict(X_test).tolist()
    truth_LR += y_test.tolist()
# Out:
#           10-norm    2-norm    3-norm    5-norm    7-norm  \
# 13173    0.750000  0.770552  0.752308  0.750039  0.750001
# 865100   0.372041  0.577350  0.480750  0.415244  0.389977
# 1115306  0.500098  0.612372  0.538609  0.506099  0.501109
# 757898   0.535887  0.707107  0.629961  0.574349  0.552045
# 1045471  0.500098  0.612372  0.538609  0.506099  0.501109
# ...           ...       ...       ...       ...       ...
# 756204   0.535887  0.707107  0.629961  0.574349  0.552045
# 444094   0.500098  0.612372  0.538609  0.506099  0.501109
# 529414   0.500098  0.612372  0.538609  0.506099  0.501109
# 842145   0.372041  0.577350  0.480750  0.415244  0.389977
# 298340   0.750001  0.790569  0.759147  0.750616  0.750049
#
#          MagpieData avg_dev AtomicWeight  MagpieData avg_dev Column  \
# 13173                          19.531630                   4.687500
# 865100                         35.725591                   4.666667
# 1115306                        64.549350                   3.000000
# 757898                         31.569250                   5.000000
# 1045471                        41.703225                   2.500000
# ...                                  ...                        ...
# 756204                         32.121231                   4.500000
# 444094                         76.293795                   3.750000
# 529414                         62.060527                   3.375000
# 842145                         66.102578                   3.111111
# 298340                         32.263447                   0.000000
#
#          MagpieData avg_dev CovalentRadius  \
# 13173                            40.125000
# 865100                           27.777778
# 1115306                           8.750000
# 757898                           32.000000
# 1045471                          39.750000
# ...                                    ...
# 756204                           27.000000
# 444094                           10.875000
# 529414                           25.250000
# 842145                            8.222222
# 298340                            0.375000
#
#          MagpieData avg_dev Electronegativity  MagpieData avg_dev GSbandgap  \
# 13173                                0.937500                       0.73875
# 865100                               0.297778                       0.00000
# 1115306                              0.081250                       0.00000
# 757898                               0.285000                       0.38650
# 1045471                              0.427500                       0.00000
# ...                                       ...                           ...
# 756204                               0.140000                       0.00000
# 444094                               0.280000                       0.00000
# 529414                               0.222500                       0.17400
# 842145                               0.331111                       0.00000
# 298340                               0.129375                       0.00000
#
#          ...  range local difference in NfUnfilled  \
# 13173    ...                              0.000000
# 865100   ...                              5.999999
# 1115306  ...                              0.000000
# 757898   ...                              0.000000
# 1045471  ...                              0.000000
# ...      ...                                   ...
# 756204   ...                              0.000000
# 444094   ...                              0.000000
# 529414   ...                              8.535898
# 842145   ...                              0.000000
# 298340   ...                              2.021076
#
#          range local difference in NfValence  \
# 13173                           0.000000e+00
# 865100                          5.112582e+00
# 1115306                         1.847837e-10
# 757898                          0.000000e+00
# 1045471                         0.000000e+00
# ...                                      ...
# 756204                          0.000000e+00
# 444094                          8.478551e-12
# 529414                          2.327972e+00
# 842145                          6.999997e+00
# 298340                          2.021076e+00
#
#          range local difference in NpUnfilled  \
# 13173                            8.092436e-01
# 865100                           2.500000e+00
# 1115306                          3.959699e-11
# 757898                           1.368952e-01
# 1045471                          0.000000e+00
# ...                                       ...
# 756204                           1.519959e+00
# 444094                           3.879954e+00
# 529414                           1.551982e+00
# 842145                           0.000000e+00
# 298340                           0.000000e+00
#
#          range local difference in NpValence  \
# 13173                           4.046218e+00
# 865100                          4.999999e-01
# 1115306                         3.959699e-11
# 757898                          6.844760e-02
# 1045471                         0.000000e+00
# ...                                      ...
# 756204                          3.039919e-01
# 444094                          7.759908e-01
# 529414                          3.103963e+00
# 842145                          0.000000e+00
# 298340                          0.000000e+00
#
#          range local difference in NsUnfilled  \
# 13173                                0.000000
# 865100                               0.000000
# 1115306                              0.775991
# 757898                               0.000000
# 1045471                              0.775991
# ...                                       ...
# 756204                               0.000000
# 444094                               0.000000
# 529414                               0.000000
# 842145                               0.000000
# 298340                               0.000000
#
#          range local difference in NsValence  \
# 13173                               0.000000
# 865100                              0.000000
# 1115306                             0.775991
# 757898                              0.000000
# 1045471                             0.775991
# ...                                      ...
# 756204                              0.000000
# 444094                              0.000000
# 529414                              0.000000
# 842145                              0.000000
# 298340                              0.000000
#
#          range local difference in Number  range local difference in Row  \
# 13173                           26.681973                   2.521579e+00
# 865100                          13.609273                   4.999999e-01
# 1115306                         12.415852                   7.759908e-01
# 757898                           0.889819                   6.844760e-02
# 1045471                          1.551982                   9.429790e-12
# ...                                   ...                            ...
# 756204                           8.207781                   6.079838e-01
# 444094                           6.207926                   1.211031e-12
# 529414                          31.039630                   1.551982e+00
# 842145                          20.450330                   8.520971e-01
# 298340                          20.210761                   6.736920e-01
#
#          range local difference in SpaceGroupNumber  \
# 13173                                    176.569909
# 865100                                    23.432668
# 1115306                                   24.055714
# 757898                                     1.129385
# 1045471                                    0.000000
# ...                                             ...
# 756204                                     9.423749
# 444094                                    20.951751
# 529414                                    69.063178
# 842145                                    15.499993
# 298340                                    37.053061
#
#          range neighbor distance variation
# 13173                         9.573547e-02
# 865100                        6.948807e-02
# 1115306                       9.972585e-12
# 757898                        2.229431e-02
# 1045471                       1.512943e-12
# ...                                    ...
# 756204                        1.291819e-02
# 444094                        5.312348e-13
# 529414                        4.571031e-12
# 842145                        6.948735e-02
# 298340                        1.504982e-11
#
# [33333 rows x 271 columns]

# %% [markdown]
# Here is the mean absolute error (in eV/atom) for the linear regresson model:

# %%
print(mean_absolute_error(truth_LR, predictions_LR))
# Out:
# 0.2593326032220015

# %% [markdown]
# Now let's do a similar evaluation for a more complex, non-linear model, such as Random Forest. We will also time this, as it takes significant amount of time.

# %%
predictions_RF, truth_RF = [], []

for train_index, test_index in kf.split(X, y):
    
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]
    
    # Note we are reinitializing the scaler in each fold.
    scaler = StandardScaler()
    X_train = scaler.fit_transform(X_train)
    
    # This is where we train set of the current fold.
    t0 = time.time()
    regressor = RandomForestRegressor(n_estimators=20, n_jobs=-1)
    regressor.fit(X_train, y_train)
    print(time.time()-t0, ' seconds for present fold.')
    # We should properly standardize our test X with the scaler fitted in this fold.
    X_test = scaler.transform(X_test)
    
    # This is where we make prediction on test set of the current fold.
    predictions_RF += regressor.predict(X_test).tolist()
    truth_RF += y_test.tolist()
# Out:
# 12.06991720199585  seconds for present fold.
# 12.07076358795166  seconds for present fold.
# 12.169880867004395  seconds for present fold.

# %% [markdown]
# In the present problem, random forest can clearly deliver a much better CV score (in terms of mean absolute error), compared to a linear model (this may not always be the case in other ML tasks, so always check your baseline!):

# %%
print(mean_absolute_error(truth_RF, predictions_RF))
# Out:
# 0.15040050762370058

# %% [markdown]
# Let's visualize the model predictions

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
fig, axes = plt.subplots(ncols=2, sharey=True, sharex=True, figsize=(8,4))
axes[0].plot(truth_RF, predictions_RF, 'ro', alpha=0.05, markersize=2, label='random forest')
axes[1].plot(truth_LR, predictions_LR, 'bo', alpha=0.05, markersize=2, label='linear reg.')
axes[0].set_ylabel('Predicted (eV/atom)')
for i in range(2):
    axes[i].set_xlabel('DFT value (eV/atom)')
    axes[i].plot([-5,5], [-5,5], 'k--')
    axes[i].legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-433d32cc5bf4> in <module>
#       2 import matplotlib.pyplot as plt
#       3 fig, axes = plt.subplots(ncols=2, sharey=True, sharex=True, figsize=(8,4))
# ----> 4 axes[0].plot(truth_RF, predictions_RF, 'ro', alpha=0.05, markersize=2, label='random forest')
#       5 axes[1].plot(truth_LR, predictions_LR, 'bo', alpha=0.05, markersize=2, label='linear reg.')
#       6 axes[0].set_ylabel('Predicted (eV/atom)')
#
# NameError: name 'truth_RF' is not defined
